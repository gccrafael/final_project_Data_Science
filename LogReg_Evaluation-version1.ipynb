# %% [markdown]
# Building a Logistic Regression Classifier

# %%
#Read the train data
import pandas as pd

data_train = pd.read_csv('data_train.csv')
data_train = data_train.drop(['Unnamed: 0'], axis=1)

# %%
#Establish the parameters for GridSearch evaluation
from sklearn.grid_search import GridSearchCV
from sklearn.linear_model import LogisticRegression
import numpy as np

c_values = np.logspace(-30,20,50)
param_grid = {'C': c_values, 'penalty': ['l1','l2'], 'dual': [False], 'solver': ['liblinear']}
grid_search = GridSearchCV(LogisticRegression(), param_grid, scoring = 'roc_auc', verbose = 3)
grid_search.fit(data_train.drop('Y', axis=1), data_train.Y)
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# [CV] penalty=l1, C=1e-30, dual=False, solver=liblinear ...............
# [CV]  penalty=l1, C=1e-30, dual=False, solver=liblinear, score=0.500000 -   1.0s
# [CV] penalty=l1, C=1e-30, dual=False, solver=liblinear ...............
# [CV]  penalty=l1, C=1e-30, dual=False, solver=liblinear, score=0.500000 -   1.1s
# [CV] penalty=l1, C=1e-30, dual=False, solver=liblinear ...............
# [CV]  penalty=l1, C=1e-30, dual=False, solver=liblinear, score=0.500000 -   1.1s
# [CV] penalty=l2, C=1e-30, dual=False, solver=liblinear ...............
# [CV]  penalty=l2, C=1e-30, dual=False, solver=liblinear, score=0.500000 -   1.0s
# [CV] penalty=l2, C=1e-30, dual=False, solver=liblinear ...............
# [CV]  penalty=l2, C=1e-30, dual=False, solver=liblinear, score=0.500000 -   1.0s
# [CV] penalty=l2, C=1e-30, dual=False, solver=liblinear ...............
# [CV]  penalty=l2, C=1e-30, dual=False, solver=liblinear, score=0.500000 -   1.2s
# [CV] penalty=l1, C=1.04811313415e-29, dual=False, solver=liblinear ...
# [CV]  penalty=l1, C=1.04811313415e-29, dual=False, solver=liblinear, score=0.500000 -   1.0s
# [CV] penalty=l1, C=1.04811313415e-29, dual=False, solver=liblinear ...
# [CV]  penalty=l1, C=1.04811313415e-29, dual=False, solver=liblinear, score=0.500000 -   1.0s
# [CV] penalty=l1, C=1.04811313415e-29, dual=False, solver=liblinear ...
# [CV]  penalty=l1, C=1.04811313415e-29, dual=False, solver=liblinear, score=0.500000 -   1.0s
# [CV] penalty=l2, C=1.04811313415e-29, dual=False, solver=liblinear ...
# [CV]  penalty=l2, C=1.04811313415e-29, dual=False, solver=liblinear, score=0.500000 -   1.0s
# [CV] penalty=l2, C=1.04811313415e-29, dual=False, solver=liblinear ...
# [CV]  penalty=l2, C=1.04811313415e-29, dual=False, solver=liblinear, score=0.500000 -   1.1s
# [CV] penalty=l2, C=1.04811313415e-29, dual=False, solver=liblinear ...
# [CV]  penalty=l2, C=1.04811313415e-29, dual=False, solver=liblinear, score=0.500000 -   1.4s
# [CV] penalty=l1, C=1.09854114199e-28, dual=False, solver=liblinear ...
# [CV]  penalty=l1, C=1.09854114199e-28, dual=False, solver=liblinear, score=0.500000 -   1.0s
# [CV] penalty=l1, C=1.09854114199e-28, dual=False, solver=liblinear ...
# [CV]  penalty=l1, C=1.09854114199e-28, dual=False, solver=liblinear, score=0.500000 -   1.0s
# [CV] penalty=l1, C=1.09854114199e-28, dual=False, solver=liblinear ...
# [CV]  penalty=l1, C=1.09854114199e-28, dual=False, solver=liblinear, score=0.500000 -   1.0s
# [CV] penalty=l2, C=1.09854114199e-28, dual=False, solver=liblinear ...
# [CV]  penalty=l2, C=1.09854114199e-28, dual=False, solver=liblinear, score=0.500000 -   1.0s
# [CV] penalty=l2, C=1.09854114199e-28, dual=False, solver=liblinear ...
# [CV]  penalty=l2, C=1.09854114199e-28, dual=False, solver=liblinear, score=0.500000 -   1.0s
# [CV] penalty=l2, C=1.09854114199e-28, dual=False, solver=liblinear ...
# [CV]  penalty=l2, C=1.09854114199e-28, dual=False, solver=liblinear, score=0.500000 -   1.0s
# [CV] penalty=l1, C=1.15139539933e-27, dual=False, solver=liblinear ...
# [CV]  penalty=l1, C=1.15139539933e-27, dual=False, solver=liblinear, score=0.500000 -   1.1s
# [CV] penalty=l1, C=1.15139539933e-27, dual=False, solver=liblinear ...
# [CV]  penalty=l1, C=1.15139539933e-27, dual=False, solver=liblinear, score=0.500000 -   1.7s
# [CV] penalty=l1, C=1.15139539933e-27, dual=False, solver=liblinear ...
# [CV]  penalty=l1, C=1.15139539933e-27, dual=False, solver=liblinear, score=0.500000 -   1.1s
# [CV] penalty=l2, C=1.15139539933e-27, dual=False, solver=liblinear ...
# [CV]  penalty=l2, C=1.15139539933e-27, dual=False, solver=liblinear, score=0.500000 -   1.9s
# [CV] penalty=l2, C=1.15139539933e-27, dual=False, solver=liblinear ...
# [CV]  penalty=l2, C=1.15139539933e-27, dual=False, solver=liblinear, score=0.500000 -   1.2s
# [CV] penalty=l2, C=1.15139539933e-27, dual=False, solver=liblinear ...
# [CV]  penalty=l2, C=1.15139539933e-27, dual=False, solver=liblinear, score=0.500000 -   1.0s
# [CV] penalty=l1, C=1.20679264064e-26, dual=False, solver=liblinear ...
# [CV]  penalty=l1, C=1.20679264064e-26, dual=False, solver=liblinear, score=0.500000 -   1.4s
# [CV] penalty=l1, C=1.20679264064e-26, dual=False, solver=liblinear ...
# [CV]  penalty=l1, C=1.20679264064e-26, dual=False, solver=liblinear, score=0.500000 -   1.2s
# [CV] penalty=l1, C=1.20679264064e-26, dual=False, solver=liblinear ...
# [CV]  penalty=l1, C=1.20679264064e-26, dual=False, solver=liblinear, score=0.500000 -   1.0s
# [CV] penalty=l2, C=1.20679264064e-26, dual=False, solver=liblinear ...
# [CV]  penalty=l2, C=1.20679264064e-26, dual=False, solver=liblinear, score=0.500000 -   1.0s
# [CV] penalty=l2, C=1.20679264064e-26, dual=False, solver=liblinear ...
# [CV]  penalty=l2, C=1.20679264064e-26, dual=False, solver=liblinear, score=0.500000 -   1.3s
# [CV] penalty=l2, C=1.20679264064e-26, dual=False, solver=liblinear ...
# [CV]  penalty=l2, C=1.20679264064e-26, dual=False, solver=liblinear, score=0.500000 -   1.0s
# [CV] penalty=l1, C=1.26485521686e-25, dual=False, solver=liblinear ...
# [CV]  penalty=l1, C=1.26485521686e-25, dual=False, solver=liblinear, score=0.500000 -   1.0s
# [CV] penalty=l1, C=1.26485521686e-25, dual=False, solver=liblinear ...
# [CV]  penalty=l1, C=1.26485521686e-25, dual=False, solver=liblinear, score=0.500000 -   1.8s
# [Parallel(n_jobs=1)]: Done   1 jobs       | elapsed:    1.1s
# [Parallel(n_jobs=1)]: Done  32 jobs       | elapsed:   38.0s
# [CV] penalty=l1, C=1.26485521686e-25, dual=False, solver=liblinear ...
# [CV]  penalty=l1, C=1.26485521686e-25, dual=False, solver=liblinear, score=0.500000 -   1.2s
# [CV] penalty=l2, C=1.26485521686e-25, dual=False, solver=liblinear ...
# [CV]  penalty=l2, C=1.26485521686e-25, dual=False, solver=liblinear, score=0.500000 -   1.0s
# [CV] penalty=l2, C=1.26485521686e-25, dual=False, solver=liblinear ...
# [CV]  penalty=l2, C=1.26485521686e-25, dual=False, solver=liblinear, score=0.500000 -   1.0s
# [CV] penalty=l2, C=1.26485521686e-25, dual=False, solver=liblinear ...
# [CV]  penalty=l2, C=1.26485521686e-25, dual=False, solver=liblinear, score=0.500000 -   1.6s
# [CV] penalty=l1, C=1.32571136559e-24, dual=False, solver=liblinear ...
# [CV]  penalty=l1, C=1.32571136559e-24, dual=False, solver=liblinear, score=0.500000 -   1.5s
# [CV] penalty=l1, C=1.32571136559e-24, dual=False, solver=liblinear ...
# [CV]  penalty=l1, C=1.32571136559e-24, dual=False, solver=liblinear, score=0.500000 -   1.5s
# [CV] penalty=l1, C=1.32571136559e-24, dual=False, solver=liblinear ...
# [CV]  penalty=l1, C=1.32571136559e-24, dual=False, solver=liblinear, score=0.500000 -   1.1s
# [CV] penalty=l2, C=1.32571136559e-24, dual=False, solver=liblinear ...
# [CV]  penalty=l2, C=1.32571136559e-24, dual=False, solver=liblinear, score=0.500000 -   1.0s
# [CV] penalty=l2, C=1.32571136559e-24, dual=False, solver=liblinear ...
# [CV]  penalty=l2, C=1.32571136559e-24, dual=False, solver=liblinear, score=0.500000 -   1.0s
# [CV] penalty=l2, C=1.32571136559e-24, dual=False, solver=liblinear ...
# [CV]  penalty=l2, C=1.32571136559e-24, dual=False, solver=liblinear, score=0.500000 -   1.3s
# [CV] penalty=l1, C=1.38949549437e-23, dual=False, solver=liblinear ...
# [CV]  penalty=l1, C=1.38949549437e-23, dual=False, solver=liblinear, score=0.500000 -   1.1s
# [CV] penalty=l1, C=1.38949549437e-23, dual=False, solver=liblinear ...
# [CV]  penalty=l1, C=1.38949549437e-23, dual=False, solver=liblinear, score=0.500000 -   1.1s
# [CV] penalty=l1, C=1.38949549437e-23, dual=False, solver=liblinear ...
# [CV]  penalty=l1, C=1.38949549437e-23, dual=False, solver=liblinear, score=0.500000 -   1.0s
# [CV] penalty=l2, C=1.38949549437e-23, dual=False, solver=liblinear ...
# [CV]  penalty=l2, C=1.38949549437e-23, dual=False, solver=liblinear, score=0.500000 -   1.0s
# [CV] penalty=l2, C=1.38949549437e-23, dual=False, solver=liblinear ...
# [CV]  penalty=l2, C=1.38949549437e-23, dual=False, solver=liblinear, score=0.500000 -   1.0s
# [CV] penalty=l2, C=1.38949549437e-23, dual=False, solver=liblinear ...
# [CV]  penalty=l2, C=1.38949549437e-23, dual=False, solver=liblinear, score=0.500000 -   1.0s
# [CV] penalty=l1, C=1.4563484775e-22, dual=False, solver=liblinear ....
# [CV]  penalty=l1, C=1.4563484775e-22, dual=False, solver=liblinear, score=0.500000 -   1.0s
# [CV] penalty=l1, C=1.4563484775e-22, dual=False, solver=liblinear ....
# [CV]  penalty=l1, C=1.4563484775e-22, dual=False, solver=liblinear, score=0.500000 -   1.1s
# [CV] penalty=l1, C=1.4563484775e-22, dual=False, solver=liblinear ....
# [CV]  penalty=l1, C=1.4563484775e-22, dual=False, solver=liblinear, score=0.500000 -   1.0s
# [CV] penalty=l2, C=1.4563484775e-22, dual=False, solver=liblinear ....
# [CV]  penalty=l2, C=1.4563484775e-22, dual=False, solver=liblinear, score=0.500000 -   1.0s
# [CV] penalty=l2, C=1.4563484775e-22, dual=False, solver=liblinear ....
# [CV]  penalty=l2, C=1.4563484775e-22, dual=False, solver=liblinear, score=0.500000 -   1.0s
# [CV] penalty=l2, C=1.4563484775e-22, dual=False, solver=liblinear ....
# [CV]  penalty=l2, C=1.4563484775e-22, dual=False, solver=liblinear, score=0.500000 -   1.3s
# [CV] penalty=l1, C=1.52641796718e-21, dual=False, solver=liblinear ...
# [CV]  penalty=l1, C=1.52641796718e-21, dual=False, solver=liblinear, score=0.500000 -   1.1s
# [CV] penalty=l1, C=1.52641796718e-21, dual=False, solver=liblinear ...
# [CV]  penalty=l1, C=1.52641796718e-21, dual=False, solver=liblinear, score=0.500000 -   1.1s
# [CV] penalty=l1, C=1.52641796718e-21, dual=False, solver=liblinear ...
# [CV]  penalty=l1, C=1.52641796718e-21, dual=False, solver=liblinear, score=0.500000 -   1.1s
# [CV] penalty=l2, C=1.52641796718e-21, dual=False, solver=liblinear ...
# [CV]  penalty=l2, C=1.52641796718e-21, dual=False, solver=liblinear, score=0.500000 -   1.1s
# [CV] penalty=l2, C=1.52641796718e-21, dual=False, solver=liblinear ...
# [CV]  penalty=l2, C=1.52641796718e-21, dual=False, solver=liblinear, score=0.500000 -   1.0s
# [CV] penalty=l2, C=1.52641796718e-21, dual=False, solver=liblinear ...
# [CV]  penalty=l2, C=1.52641796718e-21, dual=False, solver=liblinear, score=0.500000 -   1.0s
# [CV] penalty=l1, C=1.59985871961e-20, dual=False, solver=liblinear ...
# [CV]  penalty=l1, C=1.59985871961e-20, dual=False, solver=liblinear, score=0.500000 -   1.1s
# [CV] penalty=l1, C=1.59985871961e-20, dual=False, solver=liblinear ...
# [CV]  penalty=l1, C=1.59985871961e-20, dual=False, solver=liblinear, score=0.500000 -   1.1s
# [CV] penalty=l1, C=1.59985871961e-20, dual=False, solver=liblinear ...
# [CV]  penalty=l1, C=1.59985871961e-20, dual=False, solver=liblinear, score=0.500000 -   1.1s
# [CV] penalty=l2, C=1.59985871961e-20, dual=False, solver=liblinear ...
# [CV]  penalty=l2, C=1.59985871961e-20, dual=False, solver=liblinear, score=0.500000 -   1.1s
# [CV] penalty=l2, C=1.59985871961e-20, dual=False, solver=liblinear ...
# [CV]  penalty=l2, C=1.59985871961e-20, dual=False, solver=liblinear, score=0.500000 -   1.0s
# [CV] penalty=l2, C=1.59985871961e-20, dual=False, solver=liblinear ...
# [CV]  penalty=l2, C=1.59985871961e-20, dual=False, solver=liblinear, score=0.500000 -   1.9s
# [CV] penalty=l1, C=1.67683293681e-19, dual=False, solver=liblinear ...
# [CV]  penalty=l1, C=1.67683293681e-19, dual=False, solver=liblinear, score=0.500000 -   1.3s
# [CV] penalty=l1, C=1.67683293681e-19, dual=False, solver=liblinear ...
# [CV]  penalty=l1, C=1.67683293681e-19, dual=False, solver=liblinear, score=0.500000 -   1.6s
# [CV] penalty=l1, C=1.67683293681e-19, dual=False, solver=liblinear ...
# [CV]  penalty=l1, C=1.67683293681e-19, dual=False, solver=liblinear, score=0.500000 -   1.8s
# [CV] penalty=l2, C=1.67683293681e-19, dual=False, solver=liblinear ...
# [CV]  penalty=l2, C=1.67683293681e-19, dual=False, solver=liblinear, score=0.500000 -   1.8s
# [CV] penalty=l2, C=1.67683293681e-19, dual=False, solver=liblinear ...
# [CV]  penalty=l2, C=1.67683293681e-19, dual=False, solver=liblinear, score=0.500000 -   1.6s
# [CV] penalty=l2, C=1.67683293681e-19, dual=False, solver=liblinear ...
# [CV]  penalty=l2, C=1.67683293681e-19, dual=False, solver=liblinear, score=0.500000 -   1.3s
# [CV] penalty=l1, C=1.75751062485e-18, dual=False, solver=liblinear ...
# [CV]  penalty=l1, C=1.75751062485e-18, dual=False, solver=liblinear, score=0.500000 -   1.4s
# [CV] penalty=l1, C=1.75751062485e-18, dual=False, solver=liblinear ...
# [CV]  penalty=l1, C=1.75751062485e-18, dual=False, solver=liblinear, score=0.500000 -   1.1s
# [CV] penalty=l1, C=1.75751062485e-18, dual=False, solver=liblinear ...
# [CV]  penalty=l1, C=1.75751062485e-18, dual=False, solver=liblinear, score=0.500000 -   1.1s
# [CV] penalty=l2, C=1.75751062485e-18, dual=False, solver=liblinear ...
# [CV]  penalty=l2, C=1.75751062485e-18, dual=False, solver=liblinear, score=0.500000 -   1.0s
# [CV] penalty=l2, C=1.75751062485e-18, dual=False, solver=liblinear ...
# [CV]  penalty=l2, C=1.75751062485e-18, dual=False, solver=liblinear, score=0.500000 -   1.0s
# [CV] penalty=l2, C=1.75751062485e-18, dual=False, solver=liblinear ...
# [CV]  penalty=l2, C=1.75751062485e-18, dual=False, solver=liblinear, score=0.500000 -   1.0s
# [CV] penalty=l1, C=1.84206996933e-17, dual=False, solver=liblinear ...
# [CV]  penalty=l1, C=1.84206996933e-17, dual=False, solver=liblinear, score=0.500000 -   1.0s
# [CV] penalty=l1, C=1.84206996933e-17, dual=False, solver=liblinear ...
# [CV]  penalty=l1, C=1.84206996933e-17, dual=False, solver=liblinear, score=0.500000 -   1.0s
# [CV] penalty=l1, C=1.84206996933e-17, dual=False, solver=liblinear ...
# [CV]  penalty=l1, C=1.84206996933e-17, dual=False, solver=liblinear, score=0.500000 -   1.0s
# [CV] penalty=l2, C=1.84206996933e-17, dual=False, solver=liblinear ...
# [CV]  penalty=l2, C=1.84206996933e-17, dual=False, solver=liblinear, score=0.500000 -   1.4s
# [CV] penalty=l2, C=1.84206996933e-17, dual=False, solver=liblinear ...
# [CV]  penalty=l2, C=1.84206996933e-17, dual=False, solver=liblinear, score=0.500000 -   1.2s
# [CV] penalty=l2, C=1.84206996933e-17, dual=False, solver=liblinear ...
# [CV]  penalty=l2, C=1.84206996933e-17, dual=False, solver=liblinear, score=0.500000 -   1.6s
# [CV] penalty=l1, C=1.93069772888e-16, dual=False, solver=liblinear ...
# [CV]  penalty=l1, C=1.93069772888e-16, dual=False, solver=liblinear, score=0.500000 -   1.2s
# [CV] penalty=l1, C=1.93069772888e-16, dual=False, solver=liblinear ...
# [CV]  penalty=l1, C=1.93069772888e-16, dual=False, solver=liblinear, score=0.500000 -   1.1s
# [CV] penalty=l1, C=1.93069772888e-16, dual=False, solver=liblinear ...
# [CV]  penalty=l1, C=1.93069772888e-16, dual=False, solver=liblinear, score=0.500000 -   1.2s
# [CV] penalty=l2, C=1.93069772888e-16, dual=False, solver=liblinear ...
# [CV]  penalty=l2, C=1.93069772888e-16, dual=False, solver=liblinear, score=0.500000 -   1.1s
# [CV] penalty=l2, C=1.93069772888e-16, dual=False, solver=liblinear ...
# [CV]  penalty=l2, C=1.93069772888e-16, dual=False, solver=liblinear, score=0.500000 -   1.0s
# [CV] penalty=l2, C=1.93069772888e-16, dual=False, solver=liblinear ...
# [CV]  penalty=l2, C=1.93069772888e-16, dual=False, solver=liblinear, score=0.500000 -   1.1s
# [CV] penalty=l1, C=2.02358964773e-15, dual=False, solver=liblinear ...
# [CV]  penalty=l1, C=2.02358964773e-15, dual=False, solver=liblinear, score=0.500000 -   1.4s
# [CV] penalty=l1, C=2.02358964773e-15, dual=False, solver=liblinear ...
# [CV]  penalty=l1, C=2.02358964773e-15, dual=False, solver=liblinear, score=0.500000 -   1.1s
# [CV] penalty=l1, C=2.02358964773e-15, dual=False, solver=liblinear ...
# [CV]  penalty=l1, C=2.02358964773e-15, dual=False, solver=liblinear, score=0.500000 -   1.1s
# [CV] penalty=l2, C=2.02358964773e-15, dual=False, solver=liblinear ...
# [CV]  penalty=l2, C=2.02358964773e-15, dual=False, solver=liblinear, score=0.500000 -   1.0s
# [CV] penalty=l2, C=2.02358964773e-15, dual=False, solver=liblinear ...
# [CV]  penalty=l2, C=2.02358964773e-15, dual=False, solver=liblinear, score=0.500000 -   1.1s
# [CV] penalty=l2, C=2.02358964773e-15, dual=False, solver=liblinear ...
# [CV]  penalty=l2, C=2.02358964773e-15, dual=False, solver=liblinear, score=0.500000 -   1.1s
# [CV] penalty=l1, C=2.12095088792e-14, dual=False, solver=liblinear ...
# [CV]  penalty=l1, C=2.12095088792e-14, dual=False, solver=liblinear, score=0.500000 -   1.1s
# [CV] penalty=l1, C=2.12095088792e-14, dual=False, solver=liblinear ...
# [CV]  penalty=l1, C=2.12095088792e-14, dual=False, solver=liblinear, score=0.500000 -   1.1s
# [CV] penalty=l1, C=2.12095088792e-14, dual=False, solver=liblinear ...
# [CV]  penalty=l1, C=2.12095088792e-14, dual=False, solver=liblinear, score=0.500000 -   1.1s
# [CV] penalty=l2, C=2.12095088792e-14, dual=False, solver=liblinear ...
# [CV]  penalty=l2, C=2.12095088792e-14, dual=False, solver=liblinear, score=0.500000 -   1.0s
# [CV] penalty=l2, C=2.12095088792e-14, dual=False, solver=liblinear ...
# [CV]  penalty=l2, C=2.12095088792e-14, dual=False, solver=liblinear, score=0.500000 -   1.1s
# [CV] penalty=l2, C=2.12095088792e-14, dual=False, solver=liblinear ...
# [CV]  penalty=l2, C=2.12095088792e-14, dual=False, solver=liblinear, score=0.500000 -   1.1s
# [CV] penalty=l1, C=2.22299648253e-13, dual=False, solver=liblinear ...
# [CV]  penalty=l1, C=2.22299648253e-13, dual=False, solver=liblinear, score=0.500000 -   1.1s
# [CV] penalty=l1, C=2.22299648253e-13, dual=False, solver=liblinear ...
# [CV]  penalty=l1, C=2.22299648253e-13, dual=False, solver=liblinear, score=0.500000 -   1.0s
# [CV] penalty=l1, C=2.22299648253e-13, dual=False, solver=liblinear ...
# [CV]  penalty=l1, C=2.22299648253e-13, dual=False, solver=liblinear, score=0.500000 -   1.1s
# [CV] penalty=l2, C=2.22299648253e-13, dual=False, solver=liblinear ...
# [CV]  penalty=l2, C=2.22299648253e-13, dual=False, solver=liblinear, score=0.499994 -   1.1s
# [CV] penalty=l2, C=2.22299648253e-13, dual=False, solver=liblinear ...
# [CV]  penalty=l2, C=2.22299648253e-13, dual=False, solver=liblinear, score=0.500006 -   1.2s
# [CV] penalty=l2, C=2.22299648253e-13, dual=False, solver=liblinear ...
# [CV]  penalty=l2, C=2.22299648253e-13, dual=False, solver=liblinear, score=0.500006 -   1.6s
# [CV] penalty=l1, C=2.32995181052e-12, dual=False, solver=liblinear ...
# [CV]  penalty=l1, C=2.32995181052e-12, dual=False, solver=liblinear, score=0.500000 -   1.2s
# [CV] penalty=l1, C=2.32995181052e-12, dual=False, solver=liblinear ...
# [CV]  penalty=l1, C=2.32995181052e-12, dual=False, solver=liblinear, score=0.500000 -   1.2s
# [CV] penalty=l1, C=2.32995181052e-12, dual=False, solver=liblinear ...
# [CV]  penalty=l1, C=2.32995181052e-12, dual=False, solver=liblinear, score=0.500000 -   1.3s
# [CV] penalty=l2, C=2.32995181052e-12, dual=False, solver=liblinear ...
# [CV]  penalty=l2, C=2.32995181052e-12, dual=False, solver=liblinear, score=0.500331 -   1.1s
# [CV] penalty=l2, C=2.32995181052e-12, dual=False, solver=liblinear ...
# [CV]  penalty=l2, C=2.32995181052e-12, dual=False, solver=liblinear, score=0.500292 -   1.1s
# [CV] penalty=l2, C=2.32995181052e-12, dual=False, solver=liblinear ...
# [CV]  penalty=l2, C=2.32995181052e-12, dual=False, solver=liblinear, score=0.500390 -   1.1s
# [CV] penalty=l1, C=2.44205309455e-11, dual=False, solver=liblinear ...
# [CV]  penalty=l1, C=2.44205309455e-11, dual=False, solver=liblinear, score=0.500000 -   1.2s
# [CV] penalty=l1, C=2.44205309455e-11, dual=False, solver=liblinear ...
# [CV]  penalty=l1, C=2.44205309455e-11, dual=False, solver=liblinear, score=0.500000 -   1.2s
# [CV] penalty=l1, C=2.44205309455e-11, dual=False, solver=liblinear ...
# [CV]  penalty=l1, C=2.44205309455e-11, dual=False, solver=liblinear, score=0.500000 -   1.1s
# [CV] penalty=l2, C=2.44205309455e-11, dual=False, solver=liblinear ...
# [CV]  penalty=l2, C=2.44205309455e-11, dual=False, solver=liblinear, score=0.501805 -   1.0s
# [CV] penalty=l2, C=2.44205309455e-11, dual=False, solver=liblinear ...
# [CV]  penalty=l2, C=2.44205309455e-11, dual=False, solver=liblinear, score=0.501828 -   1.0s
# [CV] penalty=l2, C=2.44205309455e-11, dual=False, solver=liblinear ...
# [CV]  penalty=l2, C=2.44205309455e-11, dual=False, solver=liblinear, score=0.501708 -   1.0s
# [CV] penalty=l1, C=2.5595479227e-10, dual=False, solver=liblinear ....
# [CV]  penalty=l1, C=2.5595479227e-10, dual=False, solver=liblinear, score=0.500000 -   1.1s
# [CV] penalty=l1, C=2.5595479227e-10, dual=False, solver=liblinear ....
# [CV]  penalty=l1, C=2.5595479227e-10, dual=False, solver=liblinear, score=0.500000 -   1.1s
# [CV] penalty=l1, C=2.5595479227e-10, dual=False, solver=liblinear ....
# [CV]  penalty=l1, C=2.5595479227e-10, dual=False, solver=liblinear, score=0.500000 -   1.0s
# [CV] penalty=l2, C=2.5595479227e-10, dual=False, solver=liblinear ....
# [CV]  penalty=l2, C=2.5595479227e-10, dual=False, solver=liblinear, score=0.692864 -   1.0s
# [CV] penalty=l2, C=2.5595479227e-10, dual=False, solver=liblinear ....
# [CV]  penalty=l2, C=2.5595479227e-10, dual=False, solver=liblinear, score=0.691509 -   1.0s
# [CV] penalty=l2, C=2.5595479227e-10, dual=False, solver=liblinear ....
# [CV]  penalty=l2, C=2.5595479227e-10, dual=False, solver=liblinear, score=0.693173 -   1.0s
# [CV] penalty=l1, C=2.68269579528e-09, dual=False, solver=liblinear ...
# [CV]  penalty=l1, C=2.68269579528e-09, dual=False, solver=liblinear, score=0.500000 -   1.1s
# [CV] penalty=l1, C=2.68269579528e-09, dual=False, solver=liblinear ...
# [CV]  penalty=l1, C=2.68269579528e-09, dual=False, solver=liblinear, score=0.500000 -   1.1s
# [CV] penalty=l1, C=2.68269579528e-09, dual=False, solver=liblinear ...
# [CV]  penalty=l1, C=2.68269579528e-09, dual=False, solver=liblinear, score=0.500000 -   1.1s
# [CV] penalty=l2, C=2.68269579528e-09, dual=False, solver=liblinear ...
# [CV]  penalty=l2, C=2.68269579528e-09, dual=False, solver=liblinear, score=0.712139 -   1.1s
# [CV] penalty=l2, C=2.68269579528e-09, dual=False, solver=liblinear ...
# [CV]  penalty=l2, C=2.68269579528e-09, dual=False, solver=liblinear, score=0.709204 -   1.1s
# [CV] penalty=l2, C=2.68269579528e-09, dual=False, solver=liblinear ...
# [CV]  penalty=l2, C=2.68269579528e-09, dual=False, solver=liblinear, score=0.710551 -   1.3s
# [CV] penalty=l1, C=2.81176869797e-08, dual=False, solver=liblinear ...
# [CV]  penalty=l1, C=2.81176869797e-08, dual=False, solver=liblinear, score=0.500000 -   1.2s
# [CV] penalty=l1, C=2.81176869797e-08, dual=False, solver=liblinear ...
# [CV]  penalty=l1, C=2.81176869797e-08, dual=False, solver=liblinear, score=0.500000 -   1.2s
# [CV] penalty=l1, C=2.81176869797e-08, dual=False, solver=liblinear ...
# [CV]  penalty=l1, C=2.81176869797e-08, dual=False, solver=liblinear, score=0.500000 -   1.4s
# [CV] penalty=l2, C=2.81176869797e-08, dual=False, solver=liblinear ...
# [CV]  penalty=l2, C=2.81176869797e-08, dual=False, solver=liblinear, score=0.712181 -   1.5s
# [CV] penalty=l2, C=2.81176869797e-08, dual=False, solver=liblinear ...
# [CV]  penalty=l2, C=2.81176869797e-08, dual=False, solver=liblinear, score=0.709249 -   1.6s
# [CV] penalty=l2, C=2.81176869797e-08, dual=False, solver=liblinear ...
# [CV]  penalty=l2, C=2.81176869797e-08, dual=False, solver=liblinear, score=0.710599 -   1.4s
# [CV] penalty=l1, C=2.94705170255e-07, dual=False, solver=liblinear ...
# [CV]  penalty=l1, C=2.94705170255e-07, dual=False, solver=liblinear, score=0.500000 -   1.2s
# [CV] penalty=l1, C=2.94705170255e-07, dual=False, solver=liblinear ...
# [CV]  penalty=l1, C=2.94705170255e-07, dual=False, solver=liblinear, score=0.500000 -   1.2s
# [CV] penalty=l1, C=2.94705170255e-07, dual=False, solver=liblinear ...
# [CV]  penalty=l1, C=2.94705170255e-07, dual=False, solver=liblinear, score=0.500000 -   1.3s
# [CV] penalty=l2, C=2.94705170255e-07, dual=False, solver=liblinear ...
# [CV]  penalty=l2, C=2.94705170255e-07, dual=False, solver=liblinear, score=0.712619 -   1.5s
# [CV] penalty=l2, C=2.94705170255e-07, dual=False, solver=liblinear ...
# [CV]  penalty=l2, C=2.94705170255e-07, dual=False, solver=liblinear, score=0.709701 -   1.2s
# [CV] penalty=l2, C=2.94705170255e-07, dual=False, solver=liblinear ...
# [CV]  penalty=l2, C=2.94705170255e-07, dual=False, solver=liblinear, score=0.711071 -   1.1s
# [CV] penalty=l1, C=3.08884359648e-06, dual=False, solver=liblinear ...
# [CV]  penalty=l1, C=3.08884359648e-06, dual=False, solver=liblinear, score=0.500000 -   1.0s
# [CV] penalty=l1, C=3.08884359648e-06, dual=False, solver=liblinear ...
# [CV]  penalty=l1, C=3.08884359648e-06, dual=False, solver=liblinear, score=0.500000 -   1.1s
# [CV] penalty=l1, C=3.08884359648e-06, dual=False, solver=liblinear ...
# [CV]  penalty=l1, C=3.08884359648e-06, dual=False, solver=liblinear, score=0.500000 -   1.0s
# [CV] penalty=l2, C=3.08884359648e-06, dual=False, solver=liblinear ...
# [CV]  penalty=l2, C=3.08884359648e-06, dual=False, solver=liblinear, score=0.716361 -   1.4s
# [CV] penalty=l2, C=3.08884359648e-06, dual=False, solver=liblinear ...
# [CV]  penalty=l2, C=3.08884359648e-06, dual=False, solver=liblinear, score=0.713589 -   1.5s
# [CV] penalty=l2, C=3.08884359648e-06, dual=False, solver=liblinear ...
# [CV]  penalty=l2, C=3.08884359648e-06, dual=False, solver=liblinear, score=0.715118 -   1.4s
# [CV] penalty=l1, C=3.23745754282e-05, dual=False, solver=liblinear ...
# [CV]  penalty=l1, C=3.23745754282e-05, dual=False, solver=liblinear, score=0.500000 -   1.2s
# [CV] penalty=l1, C=3.23745754282e-05, dual=False, solver=liblinear ...
# [CV]  penalty=l1, C=3.23745754282e-05, dual=False, solver=liblinear, score=0.500000 -   1.2s
# [CV] penalty=l1, C=3.23745754282e-05, dual=False, solver=liblinear ...
# [CV]  penalty=l1, C=3.23745754282e-05, dual=False, solver=liblinear, score=0.500000 -   1.1s
# [CV] penalty=l2, C=3.23745754282e-05, dual=False, solver=liblinear ...
# [CV]  penalty=l2, C=3.23745754282e-05, dual=False, solver=liblinear, score=0.731575 -   1.4s
# [CV] penalty=l2, C=3.23745754282e-05, dual=False, solver=liblinear ...
# [CV]  penalty=l2, C=3.23745754282e-05, dual=False, solver=liblinear, score=0.729520 -   1.6s
# [CV] penalty=l2, C=3.23745754282e-05, dual=False, solver=liblinear ...
# [CV]  penalty=l2, C=3.23745754282e-05, dual=False, solver=liblinear, score=0.731776 -   1.7s
# [CV] penalty=l1, C=0.00033932217719, dual=False, solver=liblinear ....
# [CV]  penalty=l1, C=0.00033932217719, dual=False, solver=liblinear, score=0.720812 -   1.7s
# [CV] penalty=l1, C=0.00033932217719, dual=False, solver=liblinear ....
# [CV]  penalty=l1, C=0.00033932217719, dual=False, solver=liblinear, score=0.721118 -   1.8s
# [CV] penalty=l1, C=0.00033932217719, dual=False, solver=liblinear ....
# [CV]  penalty=l1, C=0.00033932217719, dual=False, solver=liblinear, score=0.723430 -   1.9s
# [CV] penalty=l2, C=0.00033932217719, dual=False, solver=liblinear ....
# [CV]  penalty=l2, C=0.00033932217719, dual=False, solver=liblinear, score=0.759563 -   1.8s
# [CV] penalty=l2, C=0.00033932217719, dual=False, solver=liblinear ....
# [CV]  penalty=l2, C=0.00033932217719, dual=False, solver=liblinear, score=0.758462 -   1.7s
# [CV] penalty=l2, C=0.00033932217719, dual=False, solver=liblinear ....
# [CV]  penalty=l2, C=0.00033932217719, dual=False, solver=liblinear, score=0.762611 -   1.7s
# [CV] penalty=l1, C=0.00355648030622, dual=False, solver=liblinear ....
# [CV]  penalty=l1, C=0.00355648030622, dual=False, solver=liblinear, score=0.762258 -   3.5s
# [CV] penalty=l1, C=0.00355648030622, dual=False, solver=liblinear ....
# [CV]  penalty=l1, C=0.00355648030622, dual=False, solver=liblinear, score=0.761321 -   3.9s
# [CV] penalty=l1, C=0.00355648030622, dual=False, solver=liblinear ....
# [CV]  penalty=l1, C=0.00355648030622, dual=False, solver=liblinear, score=0.766847 -   3.7s
# [CV] penalty=l2, C=0.00355648030622, dual=False, solver=liblinear ....
# [CV]  penalty=l2, C=0.00355648030622, dual=False, solver=liblinear, score=0.772705 -   2.1s
# [CV] penalty=l2, C=0.00355648030622, dual=False, solver=liblinear ....
# [CV]  penalty=l2, C=0.00355648030622, dual=False, solver=liblinear, score=0.772264 -   2.2s
# [CV] penalty=l2, C=0.00355648030622, dual=False, solver=liblinear ....
# [CV]  penalty=l2, C=0.00355648030622, dual=False, solver=liblinear, score=0.777735 -   2.5s
# [CV] penalty=l1, C=0.0372759372031, dual=False, solver=liblinear .....
# [CV]  penalty=l1, C=0.0372759372031, dual=False, solver=liblinear, score=0.774196 -  19.1s
# [CV] penalty=l1, C=0.0372759372031, dual=False, solver=liblinear .....
# [CV]  penalty=l1, C=0.0372759372031, dual=False, solver=liblinear, score=0.773951 -  15.3s
# [CV] penalty=l1, C=0.0372759372031, dual=False, solver=liblinear .....
# [CV]  penalty=l1, C=0.0372759372031, dual=False, solver=liblinear, score=0.779352 -  17.1s
# [CV] penalty=l2, C=0.0372759372031, dual=False, solver=liblinear .....
# [CV]  penalty=l2, C=0.0372759372031, dual=False, solver=liblinear, score=0.775740 -   3.5s
# [CV] penalty=l2, C=0.0372759372031, dual=False, solver=liblinear .....
# [CV]  penalty=l2, C=0.0372759372031, dual=False, solver=liblinear, score=0.775680 -   3.2s
# [CV] penalty=l2, C=0.0372759372031, dual=False, solver=liblinear .....
# [CV]  penalty=l2, C=0.0372759372031, dual=False, solver=liblinear, score=0.781231 -   3.8s
# [CV] penalty=l1, C=0.390693993705, dual=False, solver=liblinear ......
# [CV]  penalty=l1, C=0.390693993705, dual=False, solver=liblinear, score=0.775991 -  55.7s
# [CV] penalty=l1, C=0.390693993705, dual=False, solver=liblinear ......
# [CV]  penalty=l1, C=0.390693993705, dual=False, solver=liblinear, score=0.775950 -  52.9s
# [CV] penalty=l1, C=0.390693993705, dual=False, solver=liblinear ......
# [CV]  penalty=l1, C=0.390693993705, dual=False, solver=liblinear, score=0.781573 -  52.0s
# [CV] penalty=l2, C=0.390693993705, dual=False, solver=liblinear ......
# [CV]  penalty=l2, C=0.390693993705, dual=False, solver=liblinear, score=0.776013 -   5.7s
# [CV] penalty=l2, C=0.390693993705, dual=False, solver=liblinear ......
# [CV]  penalty=l2, C=0.390693993705, dual=False, solver=liblinear, score=0.776060 -   4.6s
# [CV] penalty=l2, C=0.390693993705, dual=False, solver=liblinear ......
# [CV]  penalty=l2, C=0.390693993705, dual=False, solver=liblinear, score=0.781696 -   6.3s
# [CV] penalty=l1, C=4.09491506238, dual=False, solver=liblinear .......
# [CV]  penalty=l1, C=4.09491506238, dual=False, solver=liblinear, score=0.775992 - 1.1min
# [CV] penalty=l1, C=4.09491506238, dual=False, solver=liblinear .......
# [CV]  penalty=l1, C=4.09491506238, dual=False, solver=liblinear, score=0.776060 - 1.6min
# [CV] penalty=l1, C=4.09491506238, dual=False, solver=liblinear .......
# [CV]  penalty=l1, C=4.09491506238, dual=False, solver=liblinear, score=0.781692 -  46.6s
# [CV] penalty=l2, C=4.09491506238, dual=False, solver=liblinear .......
# [CV]  penalty=l2, C=4.09491506238, dual=False, solver=liblinear, score=0.775996 -   8.5s
# [CV] penalty=l2, C=4.09491506238, dual=False, solver=liblinear .......
# [CV]  penalty=l2, C=4.09491506238, dual=False, solver=liblinear, score=0.776065 -  12.4s
# [CV] penalty=l2, C=4.09491506238, dual=False, solver=liblinear .......
# [CV]  penalty=l2, C=4.09491506238, dual=False, solver=liblinear, score=0.781706 -  10.8s
# [CV] penalty=l1, C=42.9193426013, dual=False, solver=liblinear .......
# [CV]  penalty=l1, C=42.9193426013, dual=False, solver=liblinear, score=0.775980 -  32.2s
# [CV] penalty=l1, C=42.9193426013, dual=False, solver=liblinear .......
# [CV]  penalty=l1, C=42.9193426013, dual=False, solver=liblinear, score=0.776055 -  31.6s
# [CV] penalty=l1, C=42.9193426013, dual=False, solver=liblinear .......
# [CV]  penalty=l1, C=42.9193426013, dual=False, solver=liblinear, score=0.781673 -  31.9s
# [CV] penalty=l2, C=42.9193426013, dual=False, solver=liblinear .......
# [CV]  penalty=l2, C=42.9193426013, dual=False, solver=liblinear, score=0.776012 -  21.4s
# [CV] penalty=l2, C=42.9193426013, dual=False, solver=liblinear .......
# [CV]  penalty=l2, C=42.9193426013, dual=False, solver=liblinear, score=0.776052 -  20.3s
# [CV] penalty=l2, C=42.9193426013, dual=False, solver=liblinear .......
# [CV]  penalty=l2, C=42.9193426013, dual=False, solver=liblinear, score=0.781688 -  18.0s
# [CV] penalty=l1, C=449.843266897, dual=False, solver=liblinear .......
# [CV]  penalty=l1, C=449.843266897, dual=False, solver=liblinear, score=0.775988 -  36.5s
# [CV] penalty=l1, C=449.843266897, dual=False, solver=liblinear .......
# [CV]  penalty=l1, C=449.843266897, dual=False, solver=liblinear, score=0.776056 -  53.7s
# [CV] penalty=l1, C=449.843266897, dual=False, solver=liblinear .......
# [CV]  penalty=l1, C=449.843266897, dual=False, solver=liblinear, score=0.781668 -  26.5s
# [CV] penalty=l2, C=449.843266897, dual=False, solver=liblinear .......
# [CV]  penalty=l2, C=449.843266897, dual=False, solver=liblinear, score=0.776015 -  21.1s
# [CV] penalty=l2, C=449.843266897, dual=False, solver=liblinear .......
# [CV]  penalty=l2, C=449.843266897, dual=False, solver=liblinear, score=0.776058 -  17.2s
# [CV] penalty=l2, C=449.843266897, dual=False, solver=liblinear .......
# [CV]  penalty=l2, C=449.843266897, dual=False, solver=liblinear, score=0.781687 -  22.3s
# [CV] penalty=l1, C=4714.86636346, dual=False, solver=liblinear .......
# [CV]  penalty=l1, C=4714.86636346, dual=False, solver=liblinear, score=0.775980 -  26.8s
# [CV] penalty=l1, C=4714.86636346, dual=False, solver=liblinear .......
# [CV]  penalty=l1, C=4714.86636346, dual=False, solver=liblinear, score=0.776058 -  45.0s
# [CV] penalty=l1, C=4714.86636346, dual=False, solver=liblinear .......
# [CV]  penalty=l1, C=4714.86636346, dual=False, solver=liblinear, score=0.781679 -  32.9s
# [CV] penalty=l2, C=4714.86636346, dual=False, solver=liblinear .......
# [CV]  penalty=l2, C=4714.86636346, dual=False, solver=liblinear, score=0.776013 -  24.5s
# [CV] penalty=l2, C=4714.86636346, dual=False, solver=liblinear .......
# [CV]  penalty=l2, C=4714.86636346, dual=False, solver=liblinear, score=0.776048 -  20.7s
# [CV] penalty=l2, C=4714.86636346, dual=False, solver=liblinear .......
# [CV]  penalty=l2, C=4714.86636346, dual=False, solver=liblinear, score=0.781692 -  30.9s
# [CV] penalty=l1, C=49417.1336132, dual=False, solver=liblinear .......
# [CV]  penalty=l1, C=49417.1336132, dual=False, solver=liblinear, score=0.775986 -  34.8s
# [CV] penalty=l1, C=49417.1336132, dual=False, solver=liblinear .......
# [CV]  penalty=l1, C=49417.1336132, dual=False, solver=liblinear, score=0.776057 -  29.4s
# [CV] penalty=l1, C=49417.1336132, dual=False, solver=liblinear .......
# [CV]  penalty=l1, C=49417.1336132, dual=False, solver=liblinear, score=0.781663 -  27.2s
# [CV] penalty=l2, C=49417.1336132, dual=False, solver=liblinear .......
# [CV]  penalty=l2, C=49417.1336132, dual=False, solver=liblinear, score=0.776014 -  21.5s
# [CV] penalty=l2, C=49417.1336132, dual=False, solver=liblinear .......
# [CV]  penalty=l2, C=49417.1336132, dual=False, solver=liblinear, score=0.776047 -  34.7s
# [CV] penalty=l2, C=49417.1336132, dual=False, solver=liblinear .......
# [CV]  penalty=l2, C=49417.1336132, dual=False, solver=liblinear, score=0.781686 -  23.3s
# [CV] penalty=l1, C=517947.467923, dual=False, solver=liblinear .......
# [CV]  penalty=l1, C=517947.467923, dual=False, solver=liblinear, score=0.775982 -  40.7s
# [CV] penalty=l1, C=517947.467923, dual=False, solver=liblinear .......
# [CV]  penalty=l1, C=517947.467923, dual=False, solver=liblinear, score=0.776058 -  35.9s
# [CV] penalty=l1, C=517947.467923, dual=False, solver=liblinear .......
# [CV]  penalty=l1, C=517947.467923, dual=False, solver=liblinear, score=0.781668 -  23.9s
# [CV] penalty=l2, C=517947.467923, dual=False, solver=liblinear .......
# [CV]  penalty=l2, C=517947.467923, dual=False, solver=liblinear, score=0.776014 -  22.1s
# [CV] penalty=l2, C=517947.467923, dual=False, solver=liblinear .......
# [CV]  penalty=l2, C=517947.467923, dual=False, solver=liblinear, score=0.776047 -  25.8s
# [CV] penalty=l2, C=517947.467923, dual=False, solver=liblinear .......
# [CV]  penalty=l2, C=517947.467923, dual=False, solver=liblinear, score=0.781687 -  24.9s
# [CV] penalty=l1, C=5428675.43932, dual=False, solver=liblinear .......
# [CV]  penalty=l1, C=5428675.43932, dual=False, solver=liblinear, score=0.775979 -  25.1s
# [CV] penalty=l1, C=5428675.43932, dual=False, solver=liblinear .......
# [CV]  penalty=l1, C=5428675.43932, dual=False, solver=liblinear, score=0.776054 -  33.9s
# [CV] penalty=l1, C=5428675.43932, dual=False, solver=liblinear .......
# [CV]  penalty=l1, C=5428675.43932, dual=False, solver=liblinear, score=0.781666 -  21.1s
# [CV] penalty=l2, C=5428675.43932, dual=False, solver=liblinear .......
# [CV]  penalty=l2, C=5428675.43932, dual=False, solver=liblinear, score=0.776013 -  22.8s
# [CV] penalty=l2, C=5428675.43932, dual=False, solver=liblinear .......
# [CV]  penalty=l2, C=5428675.43932, dual=False, solver=liblinear, score=0.776046 -  22.3s
# [CV] penalty=l2, C=5428675.43932, dual=False, solver=liblinear .......
# [CV]  penalty=l2, C=5428675.43932, dual=False, solver=liblinear, score=0.781687 -  25.5s
# [CV] penalty=l1, C=56898660.2902, dual=False, solver=liblinear .......
# [CV]  penalty=l1, C=56898660.2902, dual=False, solver=liblinear, score=0.775981 -  23.5s
# [CV] penalty=l1, C=56898660.2902, dual=False, solver=liblinear .......
# [CV]  penalty=l1, C=56898660.2902, dual=False, solver=liblinear, score=0.776055 -  35.2s
# [CV] penalty=l1, C=56898660.2902, dual=False, solver=liblinear .......
# [CV]  penalty=l1, C=56898660.2902, dual=False, solver=liblinear, score=0.781664 -  20.4s
# [CV] penalty=l2, C=56898660.2902, dual=False, solver=liblinear .......
# [CV]  penalty=l2, C=56898660.2902, dual=False, solver=liblinear, score=0.776013 -  25.6s
# [CV] penalty=l2, C=56898660.2902, dual=False, solver=liblinear .......
# [CV]  penalty=l2, C=56898660.2902, dual=False, solver=liblinear, score=0.776050 -  26.1s
# [CV] penalty=l2, C=56898660.2902, dual=False, solver=liblinear .......
# [CV]  penalty=l2, C=56898660.2902, dual=False, solver=liblinear, score=0.781688 -  21.6s
# [CV] penalty=l1, C=596362331.659, dual=False, solver=liblinear .......
# [CV]  penalty=l1, C=596362331.659, dual=False, solver=liblinear, score=0.775980 -  25.6s
# [CV] penalty=l1, C=596362331.659, dual=False, solver=liblinear .......
# [CV]  penalty=l1, C=596362331.659, dual=False, solver=liblinear, score=0.776056 -  36.9s
# [CV] penalty=l1, C=596362331.659, dual=False, solver=liblinear .......
# [CV]  penalty=l1, C=596362331.659, dual=False, solver=liblinear, score=0.781670 -  27.9s
# [CV] penalty=l2, C=596362331.659, dual=False, solver=liblinear .......
# [CV]  penalty=l2, C=596362331.659, dual=False, solver=liblinear, score=0.776014 -  23.3s
# [CV] penalty=l2, C=596362331.659, dual=False, solver=liblinear .......
# [CV]  penalty=l2, C=596362331.659, dual=False, solver=liblinear, score=0.776047 -  28.1s
# [CV] penalty=l2, C=596362331.659, dual=False, solver=liblinear .......
# [CV]  penalty=l2, C=596362331.659, dual=False, solver=liblinear, score=0.781686 -  32.2s
# [CV] penalty=l1, C=6250551925.27, dual=False, solver=liblinear .......
# [CV]  penalty=l1, C=6250551925.27, dual=False, solver=liblinear, score=0.775985 -  36.1s
# [CV] penalty=l1, C=6250551925.27, dual=False, solver=liblinear .......
# [CV]  penalty=l1, C=6250551925.27, dual=False, solver=liblinear, score=0.776056 -  37.6s
# [CV] penalty=l1, C=6250551925.27, dual=False, solver=liblinear .......
# [CV]  penalty=l1, C=6250551925.27, dual=False, solver=liblinear, score=0.781656 -  24.9s
# [CV] penalty=l2, C=6250551925.27, dual=False, solver=liblinear .......
# [CV]  penalty=l2, C=6250551925.27, dual=False, solver=liblinear, score=0.776014 -  26.6s
# [CV] penalty=l2, C=6250551925.27, dual=False, solver=liblinear .......
# [CV]  penalty=l2, C=6250551925.27, dual=False, solver=liblinear, score=0.776046 -  22.1s
# [CV] penalty=l2, C=6250551925.27, dual=False, solver=liblinear .......
# [CV]  penalty=l2, C=6250551925.27, dual=False, solver=liblinear, score=0.781682 -  20.1s
# [CV] penalty=l1, C=65512855686.0, dual=False, solver=liblinear .......
# [CV]  penalty=l1, C=65512855686.0, dual=False, solver=liblinear, score=0.775989 -  25.9s
# [CV] penalty=l1, C=65512855686.0, dual=False, solver=liblinear .......
# [CV]  penalty=l1, C=65512855686.0, dual=False, solver=liblinear, score=0.776057 -  53.5s
# [CV] penalty=l1, C=65512855686.0, dual=False, solver=liblinear .......
# [CV]  penalty=l1, C=65512855686.0, dual=False, solver=liblinear, score=0.781671 -  21.4s
# [CV] penalty=l2, C=65512855686.0, dual=False, solver=liblinear .......
# [CV]  penalty=l2, C=65512855686.0, dual=False, solver=liblinear, score=0.776013 -  22.7s
# [CV] penalty=l2, C=65512855686.0, dual=False, solver=liblinear .......
# [CV]  penalty=l2, C=65512855686.0, dual=False, solver=liblinear, score=0.776050 -  26.1s
# [CV] penalty=l2, C=65512855686.0, dual=False, solver=liblinear .......
# [CV]  penalty=l2, C=65512855686.0, dual=False, solver=liblinear, score=0.781688 -  21.9s
# [CV] penalty=l1, C=686648845004.0, dual=False, solver=liblinear ......
# [CV]  penalty=l1, C=686648845004.0, dual=False, solver=liblinear, score=0.775982 -  28.1s
# [CV] penalty=l1, C=686648845004.0, dual=False, solver=liblinear ......
# [CV]  penalty=l1, C=686648845004.0, dual=False, solver=liblinear, score=0.776056 -  52.2s
# [CV] penalty=l1, C=686648845004.0, dual=False, solver=liblinear ......
# [CV]  penalty=l1, C=686648845004.0, dual=False, solver=liblinear, score=0.781672 -  18.8s
# [CV] penalty=l2, C=686648845004.0, dual=False, solver=liblinear ......
# [CV]  penalty=l2, C=686648845004.0, dual=False, solver=liblinear, score=0.776011 -  28.0s
# [CV] penalty=l2, C=686648845004.0, dual=False, solver=liblinear ......
# [CV]  penalty=l2, C=686648845004.0, dual=False, solver=liblinear, score=0.776049 -  18.1s
# [CV] penalty=l2, C=686648845004.0, dual=False, solver=liblinear ......
# [CV]  penalty=l2, C=686648845004.0, dual=False, solver=liblinear, score=0.781686 -  22.5s
# [CV] penalty=l1, C=7.19685673001e+12, dual=False, solver=liblinear ...
# [CV]  penalty=l1, C=7.19685673001e+12, dual=False, solver=liblinear, score=0.775984 -  25.9s
# [CV] penalty=l1, C=7.19685673001e+12, dual=False, solver=liblinear ...
# [CV]  penalty=l1, C=7.19685673001e+12, dual=False, solver=liblinear, score=0.776056 -  33.2s
# [CV] penalty=l1, C=7.19685673001e+12, dual=False, solver=liblinear ...
# [CV]  penalty=l1, C=7.19685673001e+12, dual=False, solver=liblinear, score=0.781673 -  32.9s
# [CV] penalty=l2, C=7.19685673001e+12, dual=False, solver=liblinear ...
# [CV]  penalty=l2, C=7.19685673001e+12, dual=False, solver=liblinear, score=0.776014 -  22.1s
# [CV] penalty=l2, C=7.19685673001e+12, dual=False, solver=liblinear ...
# [CV]  penalty=l2, C=7.19685673001e+12, dual=False, solver=liblinear, score=0.776045 -  24.0s
# [CV] penalty=l2, C=7.19685673001e+12, dual=False, solver=liblinear ...
# [CV]  penalty=l2, C=7.19685673001e+12, dual=False, solver=liblinear, score=0.781686 -  27.2s
# [CV] penalty=l1, C=7.54312006335e+13, dual=False, solver=liblinear ...
# [CV]  penalty=l1, C=7.54312006335e+13, dual=False, solver=liblinear, score=0.775979 -  29.6s
# [CV] penalty=l1, C=7.54312006335e+13, dual=False, solver=liblinear ...
# [CV]  penalty=l1, C=7.54312006335e+13, dual=False, solver=liblinear, score=0.776056 -  35.8s
# [CV] penalty=l1, C=7.54312006335e+13, dual=False, solver=liblinear ...
# [CV]  penalty=l1, C=7.54312006335e+13, dual=False, solver=liblinear, score=0.781670 -  27.1s
# [CV] penalty=l2, C=7.54312006335e+13, dual=False, solver=liblinear ...
# [CV]  penalty=l2, C=7.54312006335e+13, dual=False, solver=liblinear, score=0.776008 -  29.1s
# [CV] penalty=l2, C=7.54312006335e+13, dual=False, solver=liblinear ...
# [CV]  penalty=l2, C=7.54312006335e+13, dual=False, solver=liblinear, score=0.776049 -  30.2s
# [CV] penalty=l2, C=7.54312006335e+13, dual=False, solver=liblinear ...
# [CV]  penalty=l2, C=7.54312006335e+13, dual=False, solver=liblinear, score=0.781688 -  24.2s
# [CV] penalty=l1, C=7.90604321091e+14, dual=False, solver=liblinear ...
# [CV]  penalty=l1, C=7.90604321091e+14, dual=False, solver=liblinear, score=0.775981 -  25.6s
# [CV] penalty=l1, C=7.90604321091e+14, dual=False, solver=liblinear ...
# [CV]  penalty=l1, C=7.90604321091e+14, dual=False, solver=liblinear, score=0.776056 -  42.0s
# [CV] penalty=l1, C=7.90604321091e+14, dual=False, solver=liblinear ...
# [CV]  penalty=l1, C=7.90604321091e+14, dual=False, solver=liblinear, score=0.781672 -  26.9s
# [CV] penalty=l2, C=7.90604321091e+14, dual=False, solver=liblinear ...
# [CV]  penalty=l2, C=7.90604321091e+14, dual=False, solver=liblinear, score=0.776011 -  36.3s
# [CV] penalty=l2, C=7.90604321091e+14, dual=False, solver=liblinear ...
# [CV]  penalty=l2, C=7.90604321091e+14, dual=False, solver=liblinear, score=0.776047 -  26.0s
# [CV] penalty=l2, C=7.90604321091e+14, dual=False, solver=liblinear ...
# [CV]  penalty=l2, C=7.90604321091e+14, dual=False, solver=liblinear, score=0.781686 -  26.0s
# [CV] penalty=l1, C=8.28642772855e+15, dual=False, solver=liblinear ...
# [CV]  penalty=l1, C=8.28642772855e+15, dual=False, solver=liblinear, score=0.775982 -  33.2s
# [CV] penalty=l1, C=8.28642772855e+15, dual=False, solver=liblinear ...
# [CV]  penalty=l1, C=8.28642772855e+15, dual=False, solver=liblinear, score=0.776058 -  45.1s
# [CV] penalty=l1, C=8.28642772855e+15, dual=False, solver=liblinear ...
# [CV]  penalty=l1, C=8.28642772855e+15, dual=False, solver=liblinear, score=0.781671 -  30.2s
# [CV] penalty=l2, C=8.28642772855e+15, dual=False, solver=liblinear ...
# [CV]  penalty=l2, C=8.28642772855e+15, dual=False, solver=liblinear, score=0.776013 -  28.2s
# [CV] penalty=l2, C=8.28642772855e+15, dual=False, solver=liblinear ...
# [CV]  penalty=l2, C=8.28642772855e+15, dual=False, solver=liblinear, score=0.776049 -  22.5s
# [CV] penalty=l2, C=8.28642772855e+15, dual=False, solver=liblinear ...
# [CV]  penalty=l2, C=8.28642772855e+15, dual=False, solver=liblinear, score=0.781686 -  24.1s
# [CV] penalty=l1, C=8.68511373751e+16, dual=False, solver=liblinear ...
# [CV]  penalty=l1, C=8.68511373751e+16, dual=False, solver=liblinear, score=0.775977 -  26.3s
# [CV] penalty=l1, C=8.68511373751e+16, dual=False, solver=liblinear ...
# [CV]  penalty=l1, C=8.68511373751e+16, dual=False, solver=liblinear, score=0.776054 -  35.8s
# [CV] penalty=l1, C=8.68511373751e+16, dual=False, solver=liblinear ...
# [CV]  penalty=l1, C=8.68511373751e+16, dual=False, solver=liblinear, score=0.781672 -  30.3s
# [CV] penalty=l2, C=8.68511373751e+16, dual=False, solver=liblinear ...
# [CV]  penalty=l2, C=8.68511373751e+16, dual=False, solver=liblinear, score=0.776008 -  33.5s
# [CV] penalty=l2, C=8.68511373751e+16, dual=False, solver=liblinear ...
# [CV]  penalty=l2, C=8.68511373751e+16, dual=False, solver=liblinear, score=0.776047 -  26.7s
# [CV] penalty=l2, C=8.68511373751e+16, dual=False, solver=liblinear ...
# [CV]  penalty=l2, C=8.68511373751e+16, dual=False, solver=liblinear, score=0.781686 -  26.1s
# [CV] penalty=l1, C=9.10298177992e+17, dual=False, solver=liblinear ...
# [CV]  penalty=l1, C=9.10298177992e+17, dual=False, solver=liblinear, score=0.775980 -  26.7s
# [CV] penalty=l1, C=9.10298177992e+17, dual=False, solver=liblinear ...
# [CV]  penalty=l1, C=9.10298177992e+17, dual=False, solver=liblinear, score=0.776058 -  43.8s
# [CV] penalty=l1, C=9.10298177992e+17, dual=False, solver=liblinear ...
# [CV]  penalty=l1, C=9.10298177992e+17, dual=False, solver=liblinear, score=0.781661 -  27.0s
# [CV] penalty=l2, C=9.10298177992e+17, dual=False, solver=liblinear ...
# [CV]  penalty=l2, C=9.10298177992e+17, dual=False, solver=liblinear, score=0.776013 -  30.8s
# [CV] penalty=l2, C=9.10298177992e+17, dual=False, solver=liblinear ...
# [CV]  penalty=l2, C=9.10298177992e+17, dual=False, solver=liblinear, score=0.776045 -  25.4s
# [CV] penalty=l2, C=9.10298177992e+17, dual=False, solver=liblinear ...
# [CV]  penalty=l2, C=9.10298177992e+17, dual=False, solver=liblinear, score=0.781686 -  28.3s
# [Parallel(n_jobs=1)]: Done 128 jobs       | elapsed:  2.5min
# [Parallel(n_jobs=1)]: Done 288 jobs       | elapsed: 60.2min
# [CV] penalty=l1, C=9.5409547635e+18, dual=False, solver=liblinear ....
# [CV]  penalty=l1, C=9.5409547635e+18, dual=False, solver=liblinear, score=0.775979 -  38.2s
# [CV] penalty=l1, C=9.5409547635e+18, dual=False, solver=liblinear ....
# [CV]  penalty=l1, C=9.5409547635e+18, dual=False, solver=liblinear, score=0.776054 -  50.6s
# [CV] penalty=l1, C=9.5409547635e+18, dual=False, solver=liblinear ....
# [CV]  penalty=l1, C=9.5409547635e+18, dual=False, solver=liblinear, score=0.781677 -  36.2s
# [CV] penalty=l2, C=9.5409547635e+18, dual=False, solver=liblinear ....
# [CV]  penalty=l2, C=9.5409547635e+18, dual=False, solver=liblinear, score=0.776014 -  26.2s
# [CV] penalty=l2, C=9.5409547635e+18, dual=False, solver=liblinear ....
# [CV]  penalty=l2, C=9.5409547635e+18, dual=False, solver=liblinear, score=0.776047 -  23.9s
# [CV] penalty=l2, C=9.5409547635e+18, dual=False, solver=liblinear ....
# [CV]  penalty=l2, C=9.5409547635e+18, dual=False, solver=liblinear, score=0.781689 -  23.1s
# [CV] penalty=l1, C=1e+20, dual=False, solver=liblinear ...............
# [CV]  penalty=l1, C=1e+20, dual=False, solver=liblinear, score=0.775985 -  34.4s
# [CV] penalty=l1, C=1e+20, dual=False, solver=liblinear ...............
# [CV]  penalty=l1, C=1e+20, dual=False, solver=liblinear, score=0.776056 -  58.6s
# [CV] penalty=l1, C=1e+20, dual=False, solver=liblinear ...............
# [CV]  penalty=l1, C=1e+20, dual=False, solver=liblinear, score=0.781684 -  37.3s
# [CV] penalty=l2, C=1e+20, dual=False, solver=liblinear ...............
# [CV]  penalty=l2, C=1e+20, dual=False, solver=liblinear, score=0.776011 -  24.3s
# [CV] penalty=l2, C=1e+20, dual=False, solver=liblinear ...............
# [CV]  penalty=l2, C=1e+20, dual=False, solver=liblinear, score=0.776050 -  22.5s
# [CV] penalty=l2, C=1e+20, dual=False, solver=liblinear ...............
# [CV]  penalty=l2, C=1e+20, dual=False, solver=liblinear, score=0.781687 -  24.4s
# [Parallel(n_jobs=1)]: Done 300 out of 300 | elapsed: 66.9min finished
# GridSearchCV(cv=None, error_score='raise',
#        estimator=LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr',
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0),
#        fit_params={}, iid=True, loss_func=None, n_jobs=1,
#        param_grid={'penalty': ['l1', 'l2'], 'C': array([  1.00000e-30,   1.04811e-29,   1.09854e-28,   1.15140e-27,
#          1.20679e-26,   1.26486e-25,   1.32571e-24,   1.38950e-23,
#          1.45635e-22,   1.52642e-21,   1.59986e-20,   1.67683e-19,
#          1.75751e-18,   1.84207e-17,   1.93070e-16,   2.0...+16,   9.10298e+17,
#          9.54095e+18,   1.00000e+20]), 'dual': [False], 'solver': ['liblinear']},
#        pre_dispatch='2*n_jobs', refit=True, score_func=None,
#        scoring='roc_auc', verbose=3)

# %%
#Read the validation data 
data_validation = pd.read_csv('data_validation.csv')
data_validation = data_validation.drop(['Unnamed: 0'], axis=1)

# %%
#Apply GridSearch to validation data and compute score
from sklearn.metrics import roc_auc_score

grid_search.predict_proba(data_validation.drop('Y', axis=1))
grid_search.score(data_validation.drop('Y', axis=1), data_validation.Y)
#auc_score = roc_auc_score(data_validation.Y, logreg.predict_proba(data_validation.drop('Y', axis=1))[:, 1])
# Out:
# /Users/Rafa/anaconda2/lib/python2.7/site-packages/sklearn/grid_search.py:370: ChangedBehaviorWarning: The long-standing behavior to use the estimator's score function in GridSearchCV.score has changed. The scoring parameter is now used.
#   ChangedBehaviorWarning)
# 0.77858912037969752

# %%
#Extract the best parameters from GridSearch
grid_search.best_params_
# Out:
# {'C': 0.39069399370546209,
#  'dual': False,
#  'penalty': 'l2',
#  'solver': 'liblinear'}

# %%
#Build function to plot ROC curve
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt 

def plotAUC(truth, pred, lab):
    fpr, tpr, thresholds = roc_curve(truth, pred)
    roc_auc = auc(fpr, tpr)
    c = (np.random.rand(), np.random.rand(), np.random.rand())
    plt.plot(fpr, tpr, color=c, label= lab+' (AUC = %0.2f)' % roc_auc)
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.0])
    plt.xlabel('FPR')
    plt.ylabel('TPR')
    plt.title('ROC')
    plt.legend(loc="lower right")

# %%
#Apply classifier having the best parameters on validation data and plot ROC curve
# %matplotlib inline
logreg = LogisticRegression(C=25.0, dual=False, penalty='l2', solver='liblinear')
logreg.fit(data_train.drop('Y', axis=1), data_train.Y)

plotAUC(data_validation.Y, logreg.predict_proba(data_validation.drop('Y', axis=1))[:,1], 'LR')    
plt.show()

# %%
datae = data_train.corr()

# %%
(datae.iloc[:]>.2).apply(pd.value_counts).fillna(True)
# Out:
#          Y  Median_income  UnitsRes  AssessTot  Avg_value_per_res_unit  \
# False  211            212       210        212                     213
# True     3              2         4          2                       1
#
#        BuildingAge  YearSinceLastAlter  Probs_in_complaint  Tot_A_violations  \
# False          211                 212                 208               210
# True             3                   2                   6                 4
#
#        Tot_B_violations    ...     Month_3  Month_11  Month_12  Month_1  \
# False               210    ...         213       213       213      213
# True                  4    ...           1         1         1        1
#
#        Month_2  Month_6  Month_9  Month_8  Month_5  Month_10
# False      213      213      213      213      213       213
# True         1        1        1        1        1         1
#
# [2 rows x 214 columns]

# %%
datae
# Out:
#                                Y  Median_income  UnitsRes  AssessTot  \
# Y                       1.000000      -0.043627 -0.021742  -0.020791
# Median_income          -0.043627       1.000000  0.017784   0.101623
# UnitsRes               -0.021742       0.017784  1.000000   0.767948
# AssessTot              -0.020791       0.101623  0.767948   1.000000
# Avg_value_per_res_unit -0.010306       0.190656  0.009666   0.054225
# BuildingAge             0.039111      -0.015192 -0.146026  -0.107065
# YearSinceLastAlter      0.032800      -0.038939 -0.063713  -0.050202
# Probs_in_complaint      0.234168      -0.061176 -0.037228  -0.034657
# Tot_A_violations        0.010149      -0.166547  0.264767   0.041115
# Tot_B_violations        0.013203      -0.169492  0.272422   0.043315
# Tot_C_violations        0.017157      -0.168136  0.128458   0.012587
# BoroughID_2             0.002310       0.249716  0.007431   0.079261
# BoroughID_3             0.012850      -0.382664  0.046667  -0.015358
# BoroughID_1             0.004050       0.015250 -0.052372  -0.049927
# BoroughID_4            -0.031068       0.184801  0.001847  -0.002214
# UnitTypeID_91           0.212491      -0.041319 -0.018717  -0.019784
# UnitTypeID_93          -0.234572       0.015188  0.025252   0.024804
# SpaceTypeID_543        -0.009702       0.021938  0.003583   0.004320
# SpaceTypeID_573         0.120206      -0.040650 -0.005395  -0.005903
# SpaceTypeID_545         0.074450      -0.017059 -0.009734  -0.010117
# SpaceTypeID_546        -0.020014       0.018096 -0.006499  -0.003777
# SpaceTypeID_547         0.044545      -0.004810 -0.004103  -0.005521
# SpaceTypeID_541         0.063504      -0.021949 -0.004825  -0.007278
# SpaceTypeID_542         0.060685      -0.002926  0.001260   0.000162
# SpaceTypeID_550         0.006420       0.016472 -0.000644   0.002177
# SpaceTypeID_571         0.027313      -0.016110  0.008129   0.002994
# SpaceTypeID_574        -0.234590       0.015188  0.025254   0.024805
# SpaceTypeID_556        -0.009257       0.020222 -0.004055  -0.001975
# SpaceTypeID_577        -0.006165       0.005870 -0.002974  -0.002035
# SpaceTypeID_548        -0.011726       0.004160 -0.003151  -0.002186
# ...                          ...            ...       ...        ...
# CodeID_2523             0.033868      -0.000379 -0.006967  -0.005957
# CodeID_634              0.008349      -0.003937 -0.004362  -0.003565
# CodeID_2463             0.028114       0.001370 -0.007016  -0.006250
# CodeID_680              0.014703      -0.002618 -0.005338  -0.004533
# CodeID_2690            -0.004267       0.006843 -0.002114  -0.000481
# CodeID_2622            -0.011541       0.023025 -0.004514  -0.001863
# CodeID_2683            -0.006252       0.019790 -0.003715  -0.001657
# CodeID_2832             0.040455      -0.005079  0.008777   0.004853
# CodeID_2791             0.033158      -0.005353 -0.000499  -0.001285
# CodeID_2542            -0.013549      -0.001129  0.001176   0.000674
# CodeID_2679             0.094958      -0.014890 -0.004696  -0.006779
# CodeID_2793             0.001547      -0.003182 -0.003697  -0.003047
# CodeID_2666             0.070999      -0.003813 -0.002670  -0.003092
# CodeID_636             -0.013345       0.006599  0.001435   0.002877
# CodeID_2705             0.018340       0.001118  0.000818   0.000928
# CodeID_2526             0.049124      -0.012821 -0.002091  -0.004946
# CodeID_2531             0.044398      -0.015988 -0.002826  -0.003560
# CodeID_2525            -0.014654       0.017855 -0.004007  -0.002916
# CodeID_617             -0.064339      -0.015328 -0.009377  -0.010601
# Month_4                -0.061316      -0.006519  0.001084   0.001742
# Month_3                -0.060034      -0.003087 -0.001426   0.002836
# Month_11               -0.001723       0.001861  0.002552  -0.001819
# Month_12                0.025289       0.003332  0.009762   0.010485
# Month_1                 0.045439       0.005247  0.000032   0.000030
# Month_2                 0.050179       0.001851 -0.005389  -0.005826
# Month_6                 0.053935      -0.003769 -0.004460  -0.004701
# Month_9                 0.051360       0.001180  0.001756   0.000429
# Month_8                 0.068295      -0.013765 -0.005086  -0.005747
# Month_5                -0.003170       0.012328  0.004189   0.005634
# Month_10               -0.059662       0.006347 -0.007908  -0.005518
#
#                         Avg_value_per_res_unit  BuildingAge  \
# Y                                    -0.010306     0.039111
# Median_income                         0.190656    -0.015192
# UnitsRes                              0.009666    -0.146026
# AssessTot                             0.054225    -0.107065
# Avg_value_per_res_unit                1.000000    -0.014638
# BuildingAge                          -0.014638     1.000000
# YearSinceLastAlter                   -0.085231     0.404805
# Probs_in_complaint                   -0.025981     0.060283
# Tot_A_violations                     -0.027783    -0.046156
# Tot_B_violations                     -0.031031    -0.050330
# Tot_C_violations                     -0.032379     0.033294
# BoroughID_2                           0.162763     0.226317
# BoroughID_3                          -0.076283    -0.031287
# BoroughID_1                          -0.056407    -0.001894
# BoroughID_4                          -0.007211    -0.202389
# UnitTypeID_91                        -0.018271    -0.012617
# UnitTypeID_93                         0.011498     0.018642
# SpaceTypeID_543                       0.004917    -0.013255
# SpaceTypeID_573                      -0.006437     0.011316
# SpaceTypeID_545                      -0.003603     0.002919
# SpaceTypeID_546                      -0.002817    -0.026371
# SpaceTypeID_547                      -0.002831     0.003579
# SpaceTypeID_541                      -0.010385     0.010570
# SpaceTypeID_542                       0.000064    -0.003393
# SpaceTypeID_550                       0.000730    -0.019214
# SpaceTypeID_571                      -0.001915     0.005121
# SpaceTypeID_574                       0.011499     0.018633
# SpaceTypeID_556                       0.000074    -0.000059
# SpaceTypeID_577                       0.001872     0.006867
# SpaceTypeID_548                       0.000972    -0.000189
# ...                                        ...          ...
# CodeID_2523                          -0.003132     0.005033
# CodeID_634                           -0.000908     0.011547
# CodeID_2463                          -0.002599     0.004388
# CodeID_680                           -0.003236     0.005601
# CodeID_2690                           0.000925     0.007559
# CodeID_2622                           0.006564    -0.020367
# CodeID_2683                           0.004290    -0.003867
# CodeID_2832                          -0.003770    -0.019209
# CodeID_2791                          -0.002511    -0.004723
# CodeID_2542                          -0.000449    -0.009079
# CodeID_2679                          -0.004265     0.010629
# CodeID_2793                          -0.002473     0.000761
# CodeID_2666                          -0.005293    -0.007984
# CodeID_636                            0.000341    -0.016032
# CodeID_2705                          -0.000741    -0.006196
# CodeID_2526                          -0.004149    -0.004720
# CodeID_2531                          -0.000849    -0.005085
# CodeID_2525                          -0.001456     0.002718
# CodeID_617                           -0.001822    -0.004669
# Month_4                               0.004898    -0.003715
# Month_3                               0.003437    -0.016273
# Month_11                             -0.005805     0.003098
# Month_12                             -0.001482     0.004879
# Month_1                              -0.000208     0.002953
# Month_2                              -0.002814     0.013694
# Month_6                              -0.003049     0.004140
# Month_9                               0.001610     0.002416
# Month_8                              -0.002921     0.004391
# Month_5                               0.004610    -0.009036
# Month_10                              0.000552     0.001308
#
#                         YearSinceLastAlter  Probs_in_complaint  \
# Y                                 0.032800            0.234168
# Median_income                    -0.038939           -0.061176
# UnitsRes                         -0.063713           -0.037228
# AssessTot                        -0.050202           -0.034657
# Avg_value_per_res_unit           -0.085231           -0.025981
# BuildingAge                       0.404805            0.060283
# YearSinceLastAlter                1.000000            0.061435
# Probs_in_complaint                0.061435            1.000000
# Tot_A_violations                 -0.008000            0.032962
# Tot_B_violations                 -0.009944            0.037921
# Tot_C_violations                  0.025180            0.034356
# BoroughID_2                      -0.266952           -0.022074
# BoroughID_3                       0.019481            0.008349
# BoroughID_1                       0.194635            0.008838
# BoroughID_4                       0.022340           -0.000126
# UnitTypeID_91                     0.022138            0.393161
# UnitTypeID_93                    -0.025767           -0.419211
# SpaceTypeID_543                  -0.005193            0.012100
# SpaceTypeID_573                   0.022485            0.211881
# SpaceTypeID_545                   0.007975            0.141969
# SpaceTypeID_546                  -0.010245           -0.101455
# SpaceTypeID_547                   0.002007            0.080876
# SpaceTypeID_541                   0.021102            0.194466
# SpaceTypeID_542                  -0.009451            0.113919
# SpaceTypeID_550                  -0.005756            0.052912
# SpaceTypeID_571                   0.002910            0.078201
# SpaceTypeID_574                  -0.025777           -0.419225
# SpaceTypeID_556                   0.003094            0.002800
# SpaceTypeID_577                   0.006831            0.015659
# SpaceTypeID_548                   0.002285           -0.007729
# ...                                    ...                 ...
# CodeID_2523                       0.012894            0.021833
# CodeID_634                        0.001350            0.016060
# CodeID_2463                       0.013484            0.026477
# CodeID_680                        0.013558           -0.000796
# CodeID_2690                      -0.000674            0.014438
# CodeID_2622                      -0.006963           -0.023824
# CodeID_2683                      -0.002782           -0.024779
# CodeID_2832                       0.001065            0.083711
# CodeID_2791                      -0.001142           -0.038922
# CodeID_2542                      -0.005965            0.011602
# CodeID_2679                       0.010402            0.068819
# CodeID_2793                       0.002484            0.028348
# CodeID_2666                       0.007538            0.061555
# CodeID_636                       -0.007378           -0.005493
# CodeID_2705                      -0.000181            0.035249
# CodeID_2526                       0.001222            0.023342
# CodeID_2531                       0.002540            0.039525
# CodeID_2525                       0.007389           -0.024996
# CodeID_617                        0.004283           -0.122971
# Month_4                          -0.007067           -0.099435
# Month_3                          -0.016783           -0.098084
# Month_11                          0.005295            0.001701
# Month_12                          0.006333            0.038923
# Month_1                           0.007157            0.062999
# Month_2                           0.003786            0.086150
# Month_6                           0.007729            0.082807
# Month_9                           0.008161            0.080042
# Month_8                           0.000991            0.093307
# Month_5                          -0.010894           -0.033492
# Month_10                          0.001170           -0.073160
#
#                         Tot_A_violations  Tot_B_violations    ...     \
# Y                               0.010149          0.013203    ...
# Median_income                  -0.166547         -0.169492    ...
# UnitsRes                        0.264767          0.272422    ...
# AssessTot                       0.041115          0.043315    ...
# Avg_value_per_res_unit         -0.027783         -0.031031    ...
# BuildingAge                    -0.046156         -0.050330    ...
# YearSinceLastAlter             -0.008000         -0.009944    ...
# Probs_in_complaint              0.032962          0.037921    ...
# Tot_A_violations                1.000000          0.928048    ...
# Tot_B_violations                0.928048          1.000000    ...
# Tot_C_violations                0.727709          0.760739    ...
# BoroughID_2                    -0.039547         -0.039670    ...
# BoroughID_3                     0.149791          0.129324    ...
# BoroughID_1                    -0.052167         -0.036917    ...
# BoroughID_4                    -0.076572         -0.071810    ...
# UnitTypeID_91                  -0.000167          0.004617    ...
# UnitTypeID_93                  -0.000446         -0.004123    ...
# SpaceTypeID_543                 0.000632         -0.000305    ...
# SpaceTypeID_573                 0.022664          0.026447    ...
# SpaceTypeID_545                 0.004264          0.003880    ...
# SpaceTypeID_546                -0.028745         -0.029133    ...
# SpaceTypeID_547                 0.004785          0.006205    ...
# SpaceTypeID_541                 0.008280          0.010864    ...
# SpaceTypeID_542                 0.001627          0.002746    ...
# SpaceTypeID_550                -0.007501         -0.008487    ...
# SpaceTypeID_571                 0.008454          0.008046    ...
# SpaceTypeID_574                -0.000443         -0.004119    ...
# SpaceTypeID_556                -0.010401         -0.012094    ...
# SpaceTypeID_577                -0.002594         -0.002480    ...
# SpaceTypeID_548                -0.006408         -0.005973    ...
# ...                                  ...               ...    ...
# CodeID_2523                    -0.003384         -0.001346    ...
# CodeID_634                      0.002278          0.002741    ...
# CodeID_2463                    -0.002531         -0.001262    ...
# CodeID_680                     -0.002773         -0.002818    ...
# CodeID_2690                    -0.002665         -0.002088    ...
# CodeID_2622                     0.002620          0.000461    ...
# CodeID_2683                    -0.008113         -0.007087    ...
# CodeID_2832                    -0.001083          0.000312    ...
# CodeID_2791                    -0.011380         -0.011746    ...
# CodeID_2542                     0.002884          0.003772    ...
# CodeID_2679                     0.008369          0.008001    ...
# CodeID_2793                     0.000523          0.000575    ...
# CodeID_2666                     0.003068          0.003158    ...
# CodeID_636                     -0.009330         -0.009041    ...
# CodeID_2705                    -0.002045          0.000325    ...
# CodeID_2526                     0.002065          0.003562    ...
# CodeID_2531                     0.002937          0.004295    ...
# CodeID_2525                    -0.007358         -0.007429    ...
# CodeID_617                      0.009898          0.009447    ...
# Month_4                        -0.009321         -0.007939    ...
# Month_3                        -0.011834         -0.009903    ...
# Month_11                        0.000031         -0.002537    ...
# Month_12                        0.003110         -0.000268    ...
# Month_1                         0.001659          0.000179    ...
# Month_2                        -0.001049          0.000626    ...
# Month_6                         0.000117          0.000593    ...
# Month_9                         0.004734          0.005873    ...
# Month_8                         0.005595          0.006145    ...
# Month_5                        -0.005290         -0.009355    ...
# Month_10                        0.004980          0.005715    ...
#
#                          Month_3  Month_11  Month_12   Month_1   Month_2  \
# Y                      -0.060034 -0.001723  0.025289  0.045439  0.050179
# Median_income          -0.003087  0.001861  0.003332  0.005247  0.001851
# UnitsRes               -0.001426  0.002552  0.009762  0.000032 -0.005389
# AssessTot               0.002836 -0.001819  0.010485  0.000030 -0.005826
# Avg_value_per_res_unit  0.003437 -0.005805 -0.001482 -0.000208 -0.002814
# BuildingAge            -0.016273  0.003098  0.004879  0.002953  0.013694
# YearSinceLastAlter     -0.016783  0.005295  0.006333  0.007157  0.003786
# Probs_in_complaint     -0.098084  0.001701  0.038923  0.062999  0.086150
# Tot_A_violations       -0.011834  0.000031  0.003110  0.001659 -0.001049
# Tot_B_violations       -0.009903 -0.002537 -0.000268  0.000179  0.000626
# Tot_C_violations       -0.010768  0.001532  0.001220 -0.002837  0.001156
# BoroughID_2            -0.003604 -0.008003  0.005488 -0.000326  0.001394
# BoroughID_3             0.000738  0.011625 -0.002717 -0.009102 -0.005560
# BoroughID_1             0.003737 -0.003953 -0.001014  0.007241  0.000297
# BoroughID_4            -0.001908  0.000238 -0.000470  0.000919  0.004464
# UnitTypeID_91          -0.072848  0.004654  0.019920  0.051418  0.068672
# UnitTypeID_93           0.102491  0.001167 -0.024139 -0.073940 -0.097635
# SpaceTypeID_543        -0.008156 -0.003151 -0.002086  0.000513  0.005015
# SpaceTypeID_573        -0.054798 -0.003430  0.018013  0.038368  0.046980
# SpaceTypeID_545        -0.008324  0.009410  0.009218  0.009602  0.020027
# SpaceTypeID_546         0.024698  0.000857 -0.019355 -0.017852 -0.019597
# SpaceTypeID_547        -0.020785  0.001553  0.007220  0.012028  0.016355
# SpaceTypeID_541        -0.045207 -0.003164  0.015547  0.030242  0.031147
# SpaceTypeID_542        -0.013639  0.005341  0.006671  0.005565  0.016766
# SpaceTypeID_550        -0.008032  0.001447  0.008573  0.013554  0.010647
# SpaceTypeID_571        -0.012505 -0.000461  0.005243  0.009962  0.009219
# SpaceTypeID_574         0.102495  0.001169 -0.024137 -0.073939 -0.097633
# SpaceTypeID_556        -0.012283 -0.009255 -0.000104  0.014618  0.010220
# SpaceTypeID_577        -0.006154 -0.003904  0.002601  0.007470  0.001736
# SpaceTypeID_548        -0.000830  0.001143 -0.000143 -0.000694 -0.003125
# ...                          ...       ...       ...       ...       ...
# CodeID_2523            -0.015026  0.007326  0.007951  0.013997  0.013037
# CodeID_634             -0.007498  0.000408  0.008352  0.004080  0.009591
# CodeID_2463            -0.016491  0.006305  0.005504  0.020139  0.012373
# CodeID_680             -0.010552 -0.001037  0.002550  0.007937  0.014416
# CodeID_2690            -0.008118 -0.003764  0.003578  0.000729  0.006607
# CodeID_2622            -0.019384 -0.005516 -0.001214  0.015575  0.023895
# CodeID_2683            -0.006470 -0.003727  0.000492  0.009139  0.005553
# CodeID_2832            -0.022383  0.004023  0.009920  0.017201  0.023305
# CodeID_2791            -0.024818 -0.009117 -0.001289  0.008809  0.020536
# CodeID_2542            -0.014489 -0.010418 -0.004928 -0.001102  0.009078
# CodeID_2679            -0.027655 -0.007137  0.007495  0.013614  0.011520
# CodeID_2793            -0.016835 -0.002283  0.003057  0.011657  0.016765
# CodeID_2666            -0.024764 -0.014441 -0.003032  0.005622  0.013919
# CodeID_636             -0.009711 -0.000872 -0.002396  0.005182  0.013715
# CodeID_2705            -0.011321  0.001224  0.001809  0.007682  0.012197
# CodeID_2526            -0.010267  0.004397  0.001199  0.006731  0.018186
# CodeID_2531            -0.013266  0.003657  0.001713  0.003542  0.013989
# CodeID_2525            -0.013259 -0.010255 -0.007969 -0.006266  0.029828
# CodeID_617              0.062806  0.022712 -0.014513 -0.037289 -0.042932
# Month_4                -0.143797 -0.119110 -0.105079 -0.091608 -0.096202
# Month_3                 1.000000 -0.120154 -0.106000 -0.092410 -0.097045
# Month_11               -0.120154  1.000000 -0.087802 -0.076545 -0.080385
# Month_12               -0.106000 -0.087802  1.000000 -0.067528 -0.070915
# Month_1                -0.092410 -0.076545 -0.067528  1.000000 -0.061824
# Month_2                -0.097045 -0.080385 -0.070915 -0.061824  1.000000
# Month_6                -0.100114 -0.082927 -0.073158 -0.063779 -0.066978
# Month_9                -0.098767 -0.081811 -0.072174 -0.062921 -0.066077
# Month_8                -0.097675 -0.080907 -0.071376 -0.062225 -0.065346
# Month_5                -0.101179 -0.083809 -0.073936 -0.064457 -0.067690
# Month_10               -0.136326 -0.112922 -0.099620 -0.086848 -0.091204
#
#                          Month_6   Month_9   Month_8   Month_5  Month_10
# Y                       0.053935  0.051360  0.068295 -0.003170 -0.059662
# Median_income          -0.003769  0.001180 -0.013765  0.012328  0.006347
# UnitsRes               -0.004460  0.001756 -0.005086  0.004189 -0.007908
# AssessTot              -0.004701  0.000429 -0.005747  0.005634 -0.005518
# Avg_value_per_res_unit -0.003049  0.001610 -0.002921  0.004610  0.000552
# BuildingAge             0.004140  0.002416  0.004391 -0.009036  0.001308
# YearSinceLastAlter      0.007729  0.008161  0.000991 -0.010894  0.001170
# Probs_in_complaint      0.082807  0.080042  0.093307 -0.033492 -0.073160
# Tot_A_violations        0.000117  0.004734  0.005595 -0.005290  0.004980
# Tot_B_violations        0.000593  0.005873  0.006145 -0.009355  0.005715
# Tot_C_violations       -0.001009 -0.000351 -0.001828 -0.010508  0.017269
# BoroughID_2            -0.012345  0.015631  0.007079  0.012993 -0.005639
# BoroughID_3            -0.008922 -0.024601 -0.009609 -0.004273  0.012722
# BoroughID_1             0.016097  0.006480  0.001207 -0.005836 -0.007563
# BoroughID_4             0.004334  0.005077 -0.000153 -0.004383  0.000645
# UnitTypeID_91           0.074396  0.073904  0.071761 -0.045783 -0.071412
# UnitTypeID_93          -0.104250 -0.105879 -0.102052  0.059430  0.095810
# SpaceTypeID_543         0.007715  0.011377  0.008301 -0.005917 -0.004579
# SpaceTypeID_573         0.051665  0.052975  0.051695 -0.014118 -0.046895
# SpaceTypeID_545         0.012769  0.010436  0.009420 -0.018256 -0.024517
# SpaceTypeID_546        -0.015240 -0.019755 -0.015482 -0.002631  0.018372
# SpaceTypeID_547         0.011129  0.022705  0.018129 -0.010171 -0.014453
# SpaceTypeID_541         0.039690  0.038999  0.038600 -0.011667 -0.029539
# SpaceTypeID_542         0.009998  0.011188  0.009735 -0.013988 -0.014392
# SpaceTypeID_550         0.007092  0.010104  0.007075 -0.005210 -0.014226
# SpaceTypeID_571         0.017103  0.014304  0.008450 -0.009141 -0.012522
# SpaceTypeID_574        -0.104249 -0.105910 -0.102051  0.059432  0.095813
# SpaceTypeID_556         0.017314  0.012806  0.017866 -0.005789 -0.010313
# SpaceTypeID_577         0.004047  0.001937  0.000213 -0.003503 -0.005262
# SpaceTypeID_548        -0.005646 -0.003340  0.000294  0.000603  0.002410
# ...                          ...       ...       ...       ...       ...
# CodeID_2523             0.008763  0.007572  0.007012 -0.006156 -0.010716
# CodeID_634              0.003885  0.006163  0.003158 -0.003065 -0.005893
# CodeID_2463             0.010539  0.005417  0.005809 -0.007074 -0.009399
# CodeID_680              0.008520  0.008845  0.007384 -0.001509 -0.008377
# CodeID_2690             0.007362  0.008106  0.005546 -0.000093 -0.004471
# CodeID_2622             0.024129  0.027206  0.020860 -0.011620 -0.019771
# CodeID_2683             0.008686  0.010576  0.008168 -0.003570 -0.005273
# CodeID_2832             0.024235  0.020453  0.023597 -0.010481 -0.027634
# CodeID_2791             0.037266  0.025059  0.023176 -0.012378 -0.013795
# CodeID_2542             0.013588  0.020440  0.017498 -0.003166 -0.001692
# CodeID_2679             0.019407  0.023517  0.029159 -0.002607 -0.010790
# CodeID_2793             0.020072  0.016858  0.018594 -0.006721 -0.009030
# CodeID_2666             0.025119  0.039616  0.031555 -0.002172 -0.010181
# CodeID_636              0.019190  0.012263  0.011248 -0.003218 -0.015375
# CodeID_2705             0.011560  0.010947  0.007444 -0.004627 -0.014804
# CodeID_2526             0.010571  0.012163  0.013453 -0.007589 -0.025197
# CodeID_2531             0.015518  0.018067  0.009298 -0.010001 -0.018397
# CodeID_2525             0.040707  0.022321  0.009513 -0.007723 -0.013405
# CodeID_617             -0.044239 -0.043629 -0.043052 -0.005176  0.014028
# Month_4                -0.099245 -0.097910 -0.096827 -0.100300 -0.135142
# Month_3                -0.100114 -0.098767 -0.097675 -0.101179 -0.136326
# Month_11               -0.082927 -0.081811 -0.080907 -0.083809 -0.112922
# Month_12               -0.073158 -0.072174 -0.071376 -0.073936 -0.099620
# Month_1                -0.063779 -0.062921 -0.062225 -0.064457 -0.086848
# Month_2                -0.066978 -0.066077 -0.065346 -0.067690 -0.091204
# Month_6                 1.000000 -0.068167 -0.067413 -0.069831 -0.094089
# Month_9                -0.068167  1.000000 -0.066506 -0.068891 -0.092823
# Month_8                -0.067413 -0.066506  1.000000 -0.068130 -0.091796
# Month_5                -0.069831 -0.068891 -0.068130  1.000000 -0.095089
# Month_10               -0.094089 -0.092823 -0.091796 -0.095089  1.000000
#
# [214 rows x 214 columns]
